# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('data/data.csv')

# %%
subset = data[data.PINCP > 0].copy()
subset.OCCP.fillna(9999, inplace=True)
total_n = len(subset)

# %%
codes = pd.read_csv('data/codes.csv')

# %%
code_name = {}
for index, row in codes.iterrows():
    try:
        code = float(row['code'])
    except ValueError:
        continue
    code_name[code] = row['occupation']

# %%
def show(low, high, subset=subset):
    subset = subset[(low <= subset.PINCP) & (subset.PINCP < high)].copy()
    n = len(subset)

    counts = dict(subset.OCCP.value_counts())

    results = []
    for code, count in counts.items():
        results.append([code_name[code], count, code, code])

    print(f'{round(100 * n / total_n, 2)}% of records {low} <= income < {high}\n')

# %%
show(0, 10_000)
show(10_000, 30_000)
show(30_000, 50_000)
show(50_000, 100_000)
show(100_000, 200_000)
show(200_000, 400_000)
show(400_000, 9e9)
# Out:
# 16.27% of records 0 <= income < 10000
#
# 29.22% of records 10000 <= income < 30000
#
# 20.19% of records 30000 <= income < 50000
#
# 22.68% of records 50000 <= income < 100000
#
# 8.58% of records 100000 <= income < 200000
#
# 2.09% of records 200000 <= income < 400000
#
# 0.96% of records 400000 <= income < 9000000000.0

# %%
def show(low, high, subset=subset):
    subset = subset[(low <= subset.PINCP) & (subset.PINCP < high)].copy()
    n = len(subset)

    counts = dict(subset.OCCP.value_counts())

    results = []
    for code, count in counts.items():
        results.append([code_name[code], count, code, code])

    print(f'{round(100 * n / total_n, 2)}% of records {low} <= income < {high}\n')

    print(sum(row[2] == row[3] for row in results), '\n')

    ordered = [row for row in sorted(results, key=lambda x: -x[1]) if row[2] == row[3]]

    print('<ul>')
    total = 0
    for name, number, first, last in ordered:
        if number / n < 0.01:
            break
        if 'Unspecified' not in name:
            total += number
        percent = f'{100 * number / n: >4.1f}'
        print(f'<li>{percent}% {name}</li>')
    print('</ul>')

    print('\n', 100 * total / n, '\n')

# %%
show(0, 10_000)
show(10_000, 30_000)
show(30_000, 50_000)
show(50_000, 100_000)
show(100_000, 200_000)
show(200_000, 400_000)
show(400_000, 9e9)
# Out:
# 16.27% of records 0 <= income < 10000
#
# 531
#
# <ul>
# <li>36.1% Unspecified; added by Aaron</li>
# <li> 4.5% Cashiers</li>
# <li> 2.7% Retail Salespersons</li>
# <li> 2.4% Waiters And Waitresses</li>
# <li> 2.1% Cooks</li>
# <li> 1.7% Laborers And Freight, Stock, And Material Movers, Hand</li>
# <li> 1.7% Janitors And Building Cleaners</li>
# <li> 1.5% Childcare Workers</li>
# <li> 1.4% Customer Service Representatives</li>
# <li> 1.3% Food Preparation Workers</li>
# <li> 1.2% Stockers And Order Fillers</li>
# <li> 1.2% Fast Food And Counter Workers</li>
# <li> 1.1% Landscaping And Groundskeeping Workers</li>
# <li> 1.1% Teaching Assistants</li>
# <li> 1.1% Maids And Housekeeping Cleaners</li>
# </ul>
#
#  24.945670204640088
#
# 29.22% of records 10000 <= income < 30000
#
# 531
#
# <ul>
# <li>34.8% Unspecified; added by Aaron</li>
# <li> 2.2% Cashiers</li>
# <li> 2.0% Retail Salespersons</li>
# <li> 1.8% Cooks</li>
# <li> 1.4% Waiters And Waitresses</li>
# <li> 1.3% First-Line Supervisors Of Retail Sales Workers</li>
# <li> 1.2% Elementary And Middle School Teachers</li>
# <li> 1.1% Teaching Assistants</li>
# <li> 1.0% Stockers And Order Fillers</li>
# </ul>
#
#  19.589538453698868
#
# 22.68% of records 50000 <= income < 100000
#
# 531
#
# <ul>
# <li>11.6% Unspecified; added by Aaron</li>
# <li> 3.7% Registered Nurses</li>
# <li> 3.0% Elementary And Middle School Teachers</li>
# <li> 3.0% Other Managers</li>
# <li> 2.5% Driver/Sales Workers And Truck Drivers</li>
# <li> 1.6% Secondary School Teachers</li>
# <li> 1.6% First-Line Supervisors Of Retail Sales Workers</li>
# <li> 1.6% Accountants And Auditors</li>
# <li> 1.3% Secretaries And Administrative Assistants, Except Legal, Medical, And Executive</li>
# <li> 1.2% Postsecondary Teachers</li>
# <li> 1.0% Financial Managers</li>
# </ul>
#
#  20.600235357481452
#
# 8.58% of records 100000 <= income < 200000
#
# 530
#
# <ul>
# <li> 7.4% Unspecified; added by Aaron</li>
# <li> 6.5% Other Managers</li>
# <li> 4.0% Software Developers</li>
# <li> 2.8% Chief Executives And Legislators</li>
# <li> 2.4% Lawyers, And Judges, Magistrates, And Other Judicial Workers</li>
# <li> 2.4% Registered Nurses</li>
# <li> 1.9% Financial Managers</li>
# <li> 1.9% Accountants And Auditors</li>
# <li> 1.7% Computer And Information Systems Managers</li>
# <li> 1.7% Postsecondary Teachers</li>
# <li> 1.7% Sales Representatives, Wholesale And Manufacturing</li>
# <li> 1.5% Management Analysts</li>
# <li> 1.4% General And Operations Managers</li>
# <li> 1.4% Other Engineers</li>
# <li> 1.3% First-Line Supervisors Of Retail Sales Workers</li>
# <li> 1.3% Education And Childcare Administrators</li>
# <li> 1.2% Construction Managers</li>
# <li> 1.2% Project Management Specialists</li>
# <li> 1.2% First-Line Supervisors Of Non-Retail Sales Workers</li>
# <li> 1.1% Pharmacists</li>
# <li> 1.1% Physicians</li>
# </ul>
#
#  39.811325354069666

# %%
subset = data[data.PINCP > 0].copy()

# %%
subset.OCCP.fillna(9999, inplace=True)

# %%
subset = subset[subset.PINCP > 800_000].copy()

# %%
codes = pd.read_csv('data/codes.csv')

# %%
code_name = {}
for index, row in codes.iterrows():
    try:
        code = float(row['code'])
    except ValueError:
        continue
    code_name[code] = row['occupation']

# %%
len(code_name)
# Out:
# 531

# %%
categories = pd.read_csv('data/categories.csv')

# %%
counts = dict(subset.OCCP.value_counts())

# %%
results = []

for code, count in counts.items():
    results.append([code_name[code], count, code, code])

for index, row in categories.iterrows():
    total = sum(count for code, count in counts.items()
                if row['lowest_code'] <= code <= row['greatest_code'])
    results.append([row['category'], total, row['lowest_code'], row['greatest_code']])

# %%
n = len(subset)

# %%
ordered = sorted(results, key=lambda x: (x[2], -x[3]))

# %%
ordered[:3]
# Out:
# [['Management, Business, Science, and Arts Occupations', 870, 10, 3550],
#  ['Management, Business, and Financial Occupations', 564, 10, 960],
#  ['Management Occupations', 429, 10, 440]]

# %%
stack = [99999]
in_list = False

for name, number, first, last in ordered:
    percent = f'{100 * number / n: >5.2f}'
    if first == last:
        if not in_list:
            print('<ul>')
            in_list = True
        print(f'<li>{percent}% {name}</li>')
        continue
    else:
        if in_list:
            print('</ul>')
            in_list = False
    # Definitely doing a span
    while first > stack[-1]:  # ending previous
        print('</details>')
        stack.pop()
    print(f'<details><summary>{percent}% {name}</summary>')
    stack.append(last)
# Out:
# <details><summary>86.57% Management, Business, Science, and Arts Occupations</summary>
# <details><summary>56.12% Management, Business, and Financial Occupations</summary>
# <details><summary>42.69% Management Occupations</summary>
# <ul>
# <li>20.80% Chief Executives And Legislators</li>
# <li> 0.70% General And Operations Managers</li>
# <li> 0.10% Advertising And Promotions Managers</li>
# <li> 0.60% Marketing Managers</li>
# <li> 0.60% Sales Managers</li>
# <li> 0.20% Computer And Information Systems Managers</li>
# <li> 3.68% Financial Managers</li>
# <li> 0.30% Industrial Production Managers</li>
# <li> 0.90% Farmers, Ranchers, And Other Agricultural Managers</li>
# <li> 1.00% Construction Managers</li>
# <li> 0.20% Architectural And Engineering Managers</li>
# <li> 0.40% Food Service Managers</li>
# <li> 0.10% Lodging Managers</li>
# <li> 0.40% Medical And Health Services Managers</li>
# <li> 1.69% Property, Real Estate, And Community Association Managers</li>
# <li>11.04% Other Managers</li>
# </ul>
# </details>
# <details><summary>13.43% Business and Financial Operations Occupations</summary>
# <ul>
# <li> 0.30% Agents And Business Managers Of Artists, Performers, And Athletes</li>
# <li> 0.10% Purchasing Agents, Except Wholesale, Retail, And Farm Products</li>
# <li> 0.10% Compliance Officers</li>
# <li> 0.20% Human Resources Workers</li>
# <li> 0.10% Project Management Specialists</li>
# <li> 2.59% Management Analysts</li>
# <li> 0.20% Market Research Analysts And Marketing Specialists</li>
# <li> 0.20% Business Operations Specialists, All Other</li>
# <li> 1.69% Accountants And Auditors</li>
# <li> 2.79% Financial And Investment Analysts</li>
# <li> 4.28% Personal Financial Advisors</li>
# <li> 0.40% Credit Counselors And Loan Officers</li>
# <li> 0.10% Tax Preparers</li>
# <li> 0.40% Other Financial Specialists</li>
# </ul>
# </details>
# </details>
# <details><summary> 4.18% Computer, Engineering, and Science Occupations</summary>
# <details><summary> 1.69% Computer and Mathematical Occupations</summary>
# <ul>
# <li> 0.10% Computer And Information Research Scientists</li>
# <li> 0.20% Computer Systems Analysts</li>
# <li> 0.20% Computer Programmers</li>
# <li> 0.80% Software Developers</li>
# <li> 0.20% Computer Support Specialists</li>
# <li> 0.10% Computer Occupations, All Other</li>
# <li> 0.10% Other Mathematical Science Occupations</li>
# </ul>
# </details>
# <details><summary> 1.59% Architecture and Engineering Occupations</summary>
# <ul>
# <li> 0.30% Architects, Except Landscape And Naval</li>
# <li> 0.10% Biomedical And Agricultural Engineers</li>
# <li> 0.30% Civil Engineers</li>
# <li> 0.10% Electrical And Electronics Engineers</li>
# <li> 0.10% Industrial Engineers, Including Health And Safety</li>
# <li> 0.20% Petroleum, Mining And Geological Engineers, Including Mining Safety Engineers</li>
# </ul>
# </details>
# <details><summary> 0.00% Material Moving Occupations</summary>
# </details>
# </details>
# </details>
# <details><summary> 0.00% Military Specific Occupations</summary>

# %%
[row for row in sorted(results, key=lambda x: -x[1]) if row[2] == row[3]][:10]
# Out:
# [['Chief Executives And Legislators', 209, 10.0, 10.0],
#  ['Other Managers', 111, 440.0, 440.0],
#  ['Physicians', 94, 3090.0, 3090.0],
#  ['Lawyers, And Judges, Magistrates, And Other Judicial Workers',
#   78,
#   2100.0,
#   2100.0],
#  ['Personal Financial Advisors', 43, 850.0, 850.0],
#  ['Financial Managers', 37, 120.0, 120.0],
#  ['Financial And Investment Analysts', 28, 845.0, 845.0],
#  ['Management Analysts', 26, 710.0, 710.0],
#  ['Securities, Commodities, And Financial Services Sales Agents',
#   25,
#   4820.0,
#   4820.0],
#  ['Surgeons', 23, 3100.0, 3100.0]]

# %%
len(results)
# Out:
# 152

# %%
print(sum(row[2] == row[3] for row in results), '\n')

ordered = [row for row in sorted(results, key=lambda x: -x[1]) if row[2] == row[3]]

print('<ul>')
total = 0
for name, number, first, last in ordered:
    if number / n < 0.01:
        break
    total += number
    percent = f'{100 * number / n: >4.1f}'
    print(f'<li>{percent}% {name}</li>')
print('</ul>')
    
print('\n', 100 * total / n)
# Out:
# 119
#
# <ul>
# <li>20.8% Chief Executives And Legislators</li>
# <li>11.0% Other Managers</li>
# <li> 9.4% Physicians</li>
# <li> 7.8% Lawyers, And Judges, Magistrates, And Other Judicial Workers</li>
# <li> 4.3% Personal Financial Advisors</li>
# <li> 3.7% Financial Managers</li>
# <li> 2.8% Financial And Investment Analysts</li>
# <li> 2.6% Management Analysts</li>
# <li> 2.5% Securities, Commodities, And Financial Services Sales Agents</li>
# <li> 2.3% Surgeons</li>
# <li> 2.0% Real Estate Brokers And Sales Agents</li>
# <li> 1.7% Property, Real Estate, And Community Association Managers</li>
# <li> 1.7% Accountants And Auditors</li>
# <li> 1.5% Postsecondary Teachers</li>
# <li> 1.4% Dentists</li>
# <li> 1.1% First-Line Supervisors Of Non-Retail Sales Workers</li>
# </ul>
#
#  76.41791044776119

# %%
results
# Out:
# [['Chief Executives And Legislators', 209, 10.0, 10.0],
#  ['Other Managers', 111, 440.0, 440.0],
#  ['Physicians', 94, 3090.0, 3090.0],
#  ['Lawyers, And Judges, Magistrates, And Other Judicial Workers',
#   78,
#   2100.0,
#   2100.0],
#  ['Personal Financial Advisors', 43, 850.0, 850.0],
#  ['Financial Managers', 37, 120.0, 120.0],
#  ['Financial And Investment Analysts', 28, 845.0, 845.0],
#  ['Management Analysts', 26, 710.0, 710.0],
#  ['Securities, Commodities, And Financial Services Sales Agents',
#   25,
#   4820.0,
#   4820.0],
#  ['Surgeons', 23, 3100.0, 3100.0],
#  ['Real Estate Brokers And Sales Agents', 20, 4920.0, 4920.0],
#  ['Property, Real Estate, And Community Association Managers',
#   17,
#   410.0,
#   410.0],
#  ['Accountants And Auditors', 17, 800.0, 800.0],
#  ['Postsecondary Teachers', 15, 2205.0, 2205.0],
#  ['Dentists', 14, 3010.0, 3010.0],
#  ['First-Line Supervisors Of Non-Retail Sales Workers', 11, 4710.0, 4710.0],
#  ['Construction Managers', 10, 220.0, 220.0],
#  ['First-Line Supervisors Of Retail Sales Workers', 10, 4700.0, 4700.0],
#  ['Sales Representatives, Wholesale And Manufacturing', 10, 4850.0, 4850.0],
#  ['Farmers, Ranchers, And Other Agricultural Managers', 9, 205.0, 205.0],
#  ['Software Developers', 8, 1021.0, 1021.0],
#  ['Sales Representatives Of Services, Except Advertising, Insurance, Financial Services, And Travel',
#   8,
#   4840.0,
#   4840.0],
#  ['General And Operations Managers', 7, 20.0, 20.0],
#  ['Marketing Managers', 6, 51.0, 51.0],
#  ['Sales Managers', 6, 52.0, 52.0],
#  ['Writers And Authors', 5, 2850.0, 2850.0],
#  ['Insurance Sales Agents', 5, 4810.0, 4810.0],
#  ['Other Engineers', 5, 1530.0, 1530.0],
#  ['Credit Counselors And Loan Officers', 4, 910.0, 910.0],
#  ['Food Service Managers', 4, 310.0, 310.0],
#  ['Physical Scientists, All Other', 4, 1760.0, 1760.0],
#  ['Medical And Health Services Managers', 4, 350.0, 350.0],
#  ['Other Financial Specialists', 4, 960.0, 960.0],
#  ['Secretaries And Administrative Assistants, Except Legal, Medical, And Executive',
#   4,
#   5740.0,
#   5740.0],
#  ['Industrial Production Managers', 3, 140.0, 140.0],
#  ['Architects, Except Landscape And Naval', 3, 1305.0, 1305.0],
#  ['Agents And Business Managers Of Artists, Performers, And Athletes',
#   3,
#   500.0,
#   500.0],
#  ['Other Financial Clerks', 3, 5165.0, 5165.0],
#  ['Producers And Directors', 3, 2710.0, 2710.0],
#  ['Civil Engineers', 3, 1360.0, 1360.0],
#  ['Personal Care Aides', 3, 3602.0, 3602.0],
#  ['Registered Nurses', 3, 3255.0, 3255.0],
#  ['Retail Salespersons', 3, 4760.0, 4760.0],
#  ['Cardiovascular Technologists and Technicians', 2, 3321.0, 3321.0],
#  ['Computer Support Specialists', 2, 1050.0, 1050.0],
#  ['Geoscientists And Hydrologists, Except Geographers', 2, 1750.0, 1750.0],
#  ['Diagnostic Medical Sonographers', 2, 3322.0, 3322.0],
#  ['Computer Systems Analysts', 2, 1006.0, 1006.0],
#  ['Cooks', 2, 4020.0, 4020.0],
#  ['Chefs And Head Cooks', 2, 4000.0, 4000.0],
#  ['Musicians and Singers', 2, 2752.0, 2752.0],
#  ['Petroleum, Mining And Geological Engineers, Including Mining Safety Engineers',
#   2,
#   1520.0,
#   1520.0],
#  ['Computer And Information Systems Managers', 2, 110.0, 110.0],
#  ['Pharmacists', 2, 3050.0, 3050.0],
#  ['Other Entertainment Attendants And Related Workers', 2, 4435.0, 4435.0],
#  ['Actors', 2, 2700.0, 2700.0],
#  ['Business Operations Specialists, All Other', 2, 750.0, 750.0],
#  ['Driver/Sales Workers And Truck Drivers', 2, 9130.0, 9130.0],
#  ['Computer Programmers', 2, 1010.0, 1010.0],
#  ['Market Research Analysts And Marketing Specialists', 2, 735.0, 735.0],
#  ['Substance Abuse And Behavioral Disorder Counselors', 2, 2001.0, 2001.0],
#  ['Human Resources Workers', 2, 630.0, 630.0],
#  ['Architectural And Engineering Managers', 2, 300.0, 300.0],
#  ['Travel Agents', 2, 4830.0, 4830.0],
#  ['Bookkeeping, Accounting, And Auditing Clerks', 1, 5120.0, 5120.0],
#  ['Landscaping And Groundskeeping Workers', 1, 4251.0, 4251.0],
#  ['Other Therapists', 1, 3245.0, 3245.0],
#  ['Veterinarians', 1, 3250.0, 3250.0],
#  ['Maintenance And Repair Workers, General', 1, 7340.0, 7340.0],
#  ['Nuclear Medicine Technologists and Medical Dosimetrists',
#   1,
#   3330.0,
#   3330.0],
#  ['Advertising Sales Agents', 1, 4800.0, 4800.0],
#  ['Automotive Body And Related Repairers', 1, 7150.0, 7150.0],
#  ['Compliance Officers', 1, 565.0, 565.0],
#  ['Radio And Telecommunications Equipment Installers And Repairers',
#   1,
#   7020.0,
#   7020.0],
#  ['Lodging Managers', 1, 340.0, 340.0],
#  ['Couriers And Messengers', 1, 5510.0, 5510.0],
#  ['Physician Assistants', 1, 3110.0, 3110.0],
#  ['Computer Occupations, All Other', 1, 1108.0, 1108.0],
#  ['Maids And Housekeeping Cleaners', 1, 4230.0, 4230.0],
#  ['Radiologic Technologists And Technicians', 1, 3323.0, 3323.0],
#  ['Cashiers', 1, 4720.0, 4720.0],
#  ['Credit Authorizers, Checkers, And Clerks', 1, 5230.0, 5230.0],
#  ['Project Management Specialists', 1, 705.0, 705.0],
#  ['Transportation Service Attendants', 1, 9365.0, 9365.0],
#  ['Educational, Guidance, And Career Counselors And Advisors',
#   1,
#   2002.0,
#   2002.0],
#  ['Clinical Laboratory Technologists And Technicians', 1, 3300.0, 3300.0],
#  ['Other Mathematical Science Occupations', 1, 1240.0, 1240.0],
#  ['Artists And Related Workers', 1, 2600.0, 2600.0],
#  ['Procurement Clerks', 1, 5150.0, 5150.0],
#  ['Other Psychologists', 1, 1825.0, 1825.0],
#  ['Janitors And Building Cleaners', 1, 4220.0, 4220.0],
#  ['Advertising And Promotions Managers', 1, 40.0, 40.0],
#  ['First-Line Supervisors Of Construction Trades And Extraction Workers',
#   1,
#   6200.0,
#   6200.0],
#  ['Biomedical And Agricultural Engineers', 1, 1340.0, 1340.0],
#  ['Other Social Scientists', 1, 1860.0, 1860.0],
#  ['Hairdressers, Hairstylists, And Cosmetologists', 1, 4510.0, 4510.0],
#  ['Broadcast Announcers And Radio Disc Jockeys', 1, 2805.0, 2805.0],
#  ['Computer And Information Research Scientists', 1, 1005.0, 1005.0],
#  ['Childcare Workers', 1, 4600.0, 4600.0],
#  ['Sales And Related Workers, All Other', 1, 4965.0, 4965.0],
#  ['Television, Video, And Film Camera Operators And Editors',
#   1,
#   2920.0,
#   2920.0],
#  ['Music Directors and Composers', 1, 2751.0, 2751.0],
#  ['Photographers', 1, 2910.0, 2910.0],
#  ['Other Teachers and Instructors', 1, 2360.0, 2360.0],
#  ['Morticians, Undertakers, And Funeral Arrangers', 1, 4465.0, 4465.0],
#  ['Electrical And Electronics Engineers', 1, 1410.0, 1410.0],
#  ['Machinists', 1, 8030.0, 8030.0],
#  ['Tax Preparers', 1, 940.0, 940.0],
#  ['Purchasing Agents, Except Wholesale, Retail, And Farm Products',
#   1,
#   530.0,
#   530.0],
#  ['Other Designers', 1, 2640.0, 2640.0],
#  ['Magnetic Resonance Imaging Technologists', 1, 3324.0, 3324.0],
#  ['Other Office And Administrative Support Workers', 1, 5940.0, 5940.0],
#  ['Other Installation, Maintenance, And Repair Workers', 1, 7640.0, 7640.0],
#  ['Athletes and Sports Competitors', 1, 2721.0, 2721.0],
#  ['Coaches and Scouts', 1, 2722.0, 2722.0],
#  ['Chemists And Materials Scientists', 1, 1720.0, 1720.0],
#  ['Loan Interviewers And Clerks', 1, 5330.0, 5330.0],
#  ['Industrial Engineers, Including Health And Safety', 1, 1430.0, 1430.0],
#  ['Security Guards And Gambling Surveillance Officers', 1, 3930.0, 3930.0],
#  ['Management, Business, Science, and Arts Occupations', 870, 10, 3550],
#  ['Management, Business, and Financial Occupations', 564, 10, 960],
#  ['Management Occupations', 429, 10, 440],
#  ['Business and Financial Operations Occupations', 135, 500, 960],
#  ['Computer, Engineering, and Science Occupations', 42, 1005, 1980],
#  ['Computer and Mathematical Occupations', 17, 1005, 1240],
#  ['Architecture and Engineering Occupations', 16, 1305, 1560],
#  ['Life, Physical, and Social Science Occupations', 9, 1600, 1980],
#  ['Education, Legal, Community Service, Arts, and Media Occupations',
#   117,
#   2001,
#   2970],
#  ['Community and Social Service Occupations', 3, 2001, 2060],
#  ['Legal Occupations', 78, 2100, 2180],
#  ['Educational Instruction, and Library Occupations', 16, 2205, 2555],
#  ['Arts, Design, Entertainment, Sports, and Media Occupations',
#   20,
#   2600,
#   2970],
#  ['Healthcare Practitioners and Technical Occupations', 147, 3000, 3550],
#  ['Service Occupations', 16, 3601, 4655],
#  ['Healthcare Support Occupations', 3, 3601, 3655],
#  ['Protective Service Occupations', 1, 3700, 3960],
#  ['Food Preparation and Serving Related Occupations', 4, 4000, 4160],
#  ['Building and Grounds Cleaning and Maintenance Occupations', 3, 4200, 4255],
#  ['Personal Care and Service Occupations', 5, 4330, 4655],
#  ['Sales and Office Occupations', 110, 4700, 5940],
#  ['Sales and Related Occupations', 97, 4700, 4965],
#  ['Office and Administrative Support Occupations', 13, 5000, 5940],
#  ['Natural Resources, Construction, and Maintenance Occupations',
#   5,
#   6005,
#   7640],
#  ['Farming, Fishing, and Forestry Occupations', 0, 6005, 6130],
#  ['Construction and Extraction Occupations', 1, 6200, 6950],
#  ['Installation, Maintenance, and Repair Occupations', 4, 7000, 7640],
#  ['Production, Transportation, and Material Moving Occupations',
#   4,
#   7700,
#   9760],
#  ['Production Occupations', 1, 7700, 8990],
#  ['Transportation and Material Moving Occupations', 3, 9005, 9760],
#  ['Transportation Occupations', 3, 9005, 9430],
#  ['Material Moving Occupations', 0, 9510, 9760],
#  ['Military Specific Occupations', 0, 9800, 9830]]
